# %%
import os
import sys
import json
import pandas as pd
sys.path.append('../src/')
from configs import *
from utils_feature_engineering import *

from matplotlib import rcParams
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
rcParams.update(fig_params)

import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Settings

# %%
data_folder = os.path.join('..', 'data')
features_folder = os.path.join('..', 'features')

train_fasta_file = os.path.join(data_folder, 'MLCPP2_Training.fasta')
test_fasta_file = os.path.join(data_folder, 'MLCPP2_Independent.fasta')

train_targets_file = os.path.join(data_folder, 'MLCPP2_TrainingCPPvalues.csv')
test_targets_file = os.path.join(data_folder, 'MLCPP2_IndependentCPPvalues.csv')

# %% [markdown]
# ## Parameters

# %%
with open(os.path.join(data_folder, 'Protein_parameters_setting.json'), 'r') as f:
    params = json.load(f)

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# ### Structure-based descriptors (Physicochemical properties)

# %%
comb = create_comb(train_fasta_file, train_targets_file, test_fasta_file, test_targets_file)

# %%
comb = add_structure_based_descriptors(df=comb, dataset_name='comb', save_folder=features_folder, return_df=True)

# %%
print(comb.shape)
comb.head()
# Out:
# (3487, 20)
#            ID                    Sequence  CPP Dataset        MW  NRB  \
# 0  Positive_1                GRKGKHKRKKLP    1   train  1432.791   54
# 1  Positive_2         KFLNRFWHWLQLKPGQPMY    1   train  2489.986   76
# 2  Positive_3    RRRRRRRRRGPGVTWTPQAWFQWV    1   train  3165.690   99
# 3  Positive_4  AEKVDPVKLNLTLSAAAEALTGLGDK    1   train  2625.020   89
# 4  Positive_5           GLKKLARLFHKLLKLGC    1   train  1938.512   70
#
#       tPSA      Fsp3     cLogP  NAR  HBD  HBA  HBD_minus_HBA  NPA  NG  \
# 0   657.21  0.730159  -6.31646    1   24   21              3    8   2
# 1   893.24  0.508197  -1.56493    8   30   29              1    7   1
# 2  1446.15  0.539007 -13.76747    7   57   38             19   12   9
# 3  1113.07  0.730435 -11.37540    0   37   38             -1    5   0
# 4   723.58  0.703297  -2.36803    2   27   25              2    6   1
#
#        NetC       IsoP  Hydrophobicity  Aromaticity  Length
# 0  7.029472  12.572391       -2.525000     0.000000      12
# 1  3.029570  10.901836       -0.726316     0.263158      19
# 2  8.994831  13.403098       -1.775000     0.166667      24
# 3 -1.005546   4.544657        0.100000     0.000000      26
# 4  4.887885  11.249135        0.341176     0.058824      17

# %% [markdown]
# ### Sequence-based descriptors

# %%
comb = create_comb(train_fasta_file, train_targets_file, test_fasta_file, test_targets_file)

# %%
comb = add_sequence_based_descriptors(df=comb, train_fasta_file=train_fasta_file, test_fasta_file=test_fasta_file,
                                      parameters_setting_file=os.path.join(data_folder, 'Protein_parameters_setting.json'),
                                      descriptors=['AAC',
                                                    'CKSAAP type 1',
                                                    'TPC type 1',  ## THIS COMPUTATION REQUIRES > 20mins
                                                    'DPC type 1',
                                                    'DDE',
                                                    'GAAC',
                                                    'CKSAAGP type 1',
                                                    'GDPC type 1',
                                                    'GTPC type 1',
                                                    'Moran',
                                                    'Geary',
                                                    'NMBroto',
                                                    'CTDC',
                                                    'CTDT',
                                                    'CTDD',
                                                    'CTriad',
                                                    'KSCTriad',
                                                    'SOCNumber',
                                                    'QSOrder',
                                                    'PAAC',
                                                    'APAAC',
                                                    'ASDC',
                                                    'AC',
                                                    'CC',
                                                    'ACC'],
                                       dataset_name='comb', save_folder=features_folder, return_df=True)
# Out:
# File imported successfully.
# File imported successfully.
# AAC: done in 0.144 s
# File imported successfully.
# File imported successfully.
# CKSAAP type 1: done in 5.784 s
# File imported successfully.
# File imported successfully.
# DPC type 1: done in 4.968 s
# File imported successfully.
# File imported successfully.
# DDE: done in 6.391 s
# File imported successfully.
# File imported successfully.
# GAAC: done in 0.069 s
# File imported successfully.
# File imported successfully.
# CKSAAGP type 1: done in 1.582 s
# File imported successfully.
# File imported successfully.
# GDPC type 1: done in 0.150 s
# File imported successfully.
# File imported successfully.
# GTPC type 1: done in 0.481 s
# File imported successfully.
# File imported successfully.
# Moran: done in 3.583 s
# File imported successfully.
# File imported successfully.
# Geary: done in 3.674 s
# File imported successfully.
# File imported successfully.
# NMBroto: done in 2.290 s
# File imported successfully.
# File imported successfully.
# CTDC: done in 0.318 s
# File imported successfully.
# File imported successfully.
# CTDT: done in 0.593 s
# File imported successfully.
# File imported successfully.
# CTDD: done in 1.821 s
# File imported successfully.
# File imported successfully.
# CTriad: done in 2.415 s
# File imported successfully.
# File imported successfully.
# KSCTriad: done in 4.791 s
# File imported successfully.
# File imported successfully.
# SOCNumber: done in 0.428 s
# File imported successfully.
# File imported successfully.
# QSOrder: done in 0.651 s
# File imported successfully.
# File imported successfully.
# PAAC: done in 0.245 s
# File imported successfully.
# File imported successfully.
# APAAC: done in 0.175 s
# File imported successfully.
# File imported successfully.
# ASDC: done in 1.555 s
# File imported successfully.
# File imported successfully.
# AC: done in 1.058 s
# File imported successfully.
# File imported successfully.
# CC: done in 8.524 s
# File imported successfully.
# File imported successfully.
# ACC: done in 9.363 s

# %%
print(comb.shape)
comb.head()
# Out:
# (3487, 5543)
#            ID                    Sequence  CPP Dataset     AAC_A     AAC_C  \
# 0  Positive_1                GRKGKHKRKKLP    1   train  0.000000  0.000000
# 1  Positive_2         KFLNRFWHWLQLKPGQPMY    1   train  0.000000  0.000000
# 2  Positive_3    RRRRRRRRRGPGVTWTPQAWFQWV    1   train  0.041667  0.000000
# 3  Positive_4  AEKVDPVKLNLTLSAAAEALTGLGDK    1   train  0.192308  0.000000
# 4  Positive_5           GLKKLARLFHKLLKLGC    1   train  0.058824  0.058824
#
#       AAC_D     AAC_E     AAC_F     AAC_G  ...  \
# 0  0.000000  0.000000  0.000000  0.166667  ...
# 1  0.000000  0.000000  0.105263  0.052632  ...
# 2  0.000000  0.000000  0.041667  0.083333  ...
# 3  0.076923  0.076923  0.000000  0.076923  ...
# 4  0.000000  0.000000  0.058824  0.117647  ...
#
#    ACC_BEGF750102_BHAR880101_lag.3  ACC_BHAR880101_BEGF750102_lag.1  \
# 0                        -0.034404                         0.072149
# 1                         0.005998                         0.035633
# 2                         0.062613                        -0.387712
# 3                         0.026399                         0.140638
# 4                        -0.162409                         0.150431
#
#    ACC_BHAR880101_BEGF750102_lag.2  ACC_BHAR880101_BEGF750102_lag.3  \
# 0                        -0.067206                         0.113576
# 1                         0.033473                        -0.054483
# 2                        -0.035798                        -0.148861
# 3                         0.021040                        -0.067608
# 4                         0.157102                        -0.339355
#
#    ACC_BEGF750103_BHAR880101_lag.1  ACC_BEGF750103_BHAR880101_lag.2  \
# 0                         0.029151                        -0.131319
# 1                        -0.016844                        -0.061969
# 2                         0.287498                         0.609847
# 3                        -0.115566                         0.170423
# 4                        -0.269119                        -0.007127
#
#    ACC_BEGF750103_BHAR880101_lag.3  ACC_BHAR880101_BEGF750103_lag.1  \
# 0                         0.067029                        -0.086821
# 1                        -0.335118                        -0.121722
# 2                        -0.080366                         0.328426
# 3                        -0.043706                        -0.079227
# 4                         0.134447                        -0.184672
#
#    ACC_BHAR880101_BEGF750103_lag.2  ACC_BHAR880101_BEGF750103_lag.3
# 0                        -0.028583                        -0.018773
# 1                         0.049401                         0.279786
# 2                        -0.000529                         0.333260
# 3                         0.072280                         0.200740
# 4                        -0.115320                         0.265157
#
# [5 rows x 5543 columns]

# %%
comb = create_comb(train_fasta_file, train_targets_file, test_fasta_file, test_targets_file)

comb = add_sequence_based_descriptors(df=comb,
                                       train_fasta_file=os.path.join(data_folder, 'MLCPP2_Training_equal_length.fasta'),
                                       test_fasta_file=os.path.join(data_folder, 'MLCPP2_Independent_equal_length.fasta'),
                                       parameters_setting_file=os.path.join(data_folder, 'Protein_parameters_setting.json'),
                                       descriptors=['EAAC',
                                                    'EGAAC',
                                                    'AAIndex',
                                                    'BLOSUM62',
                                                    'ZScale'],
                                       dataset_name='comb', save_folder=features_folder, return_df=True)
# Out:
# File imported successfully.
# File imported successfully.
# EAAC: done in 0.216 s
# File imported successfully.
# File imported successfully.
# EGAAC: done in 0.188 s
# File imported successfully.
# File imported successfully.
# AAIndex: done in 0.116 s
# File imported successfully.
# File imported successfully.
# BLOSUM62: done in 0.358 s
# File imported successfully.
# File imported successfully.
# ZScale: done in 0.101 s

# %%
print(comb.shape)
comb.head()
# Out:
# (3487, 282)
#            ID                    Sequence  CPP Dataset  EAAC_SW.1.A  \
# 0  Positive_1                GRKGKHKRKKLP    1   train         0.00
# 1  Positive_2         KFLNRFWHWLQLKPGQPMY    1   train         0.00
# 2  Positive_3    RRRRRRRRRGPGVTWTPQAWFQWV    1   train         0.00
# 3  Positive_4  AEKVDPVKLNLTLSAAAEALTGLGDK    1   train         0.25
# 4  Positive_5           GLKKLARLFHKLLKLGC    1   train         0.00
#
#    EAAC_SW.1.R  EAAC_SW.1.N  EAAC_SW.1.D  EAAC_SW.1.C  EAAC_SW.1.Q  ...  \
# 0         0.25          0.0          0.0          0.0         0.00  ...
# 1         0.00          0.0          0.0          0.0         0.25  ...
# 2         0.25          0.0          0.0          0.0         0.25  ...
# 3         0.00          0.0          0.0          0.0         0.00  ...
# 4         0.00          0.0          0.0          0.0         0.00  ...
#
#    ZScale_p5.z1  ZScale_p5.z2  ZScale_p5.z3  ZScale_p5.z4  ZScale_p5.z5  \
# 0         -4.28         -1.30         -1.49         -0.72          0.84
# 1         -2.85         -0.22          0.47          1.94         -0.98
# 2         -4.36          3.94          0.59          3.44         -1.59
# 3          3.98          0.93          1.93         -2.46          0.75
# 4          2.05         -4.06          0.36         -0.82         -0.38
#
#    ZScale_p6.z1  ZScale_p6.z2  ZScale_p6.z3  ZScale_p6.z4  ZScale_p6.z5
# 0         -1.66          0.27          1.84          0.70          2.00
# 1         -2.54          2.44          0.43          0.04         -1.47
# 2         -2.59         -2.64         -1.54         -0.85         -0.02
# 3          2.29          0.89         -2.49          1.49          0.31
# 4          0.84         -1.67          3.71          0.18         -2.65
#
# [5 rows x 282 columns]
